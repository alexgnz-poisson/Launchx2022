# %% [markdown]
# #Tu primer programa
# Para crear este programa, deberas utilizar los cocneptos que aprendiste en el ultimo modulo, usaras Jupyter Notebook en este ejercicio, que es una combinacion de texto y codigo con la que puede interactuar. Finaliza el codigo siguiente para que el resultado muestre la fecha de hoy

# %%
from datetime import date

print("Today's date is: " + str(date.today()))
# Out:
# Today's date is: 2022-02-10

# %% [markdown]
# #Construir un convertidor de unidades
# El oficial superior > Necesito una cosa mas: un programa de conversion entre parsecs y año luz.Tener un programa de este tipo podria ser realmente util en el puente para trazar nuestro curso.
# Tu > !Lo hare!

# %%
parsec = 11 
lightyears = parsec * 3.26156  

print(str(parsec) + " parsec, is " + str(lightyears)+ " lightyears")
# Out:
# 11 parsec, is 35.877159999999996 lightyears
